# %%
import numpy as np
import pandas as pd
import scipy.stats

from sklearn.model_selection import train_test_split 
from sklearn.neural_network import MLPRegressor
from sklearn import metrics
from math import sqrt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, auc

import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import talib
from numpy import mean, absolute
import yfinance as yf

import warnings
warnings.filterwarnings("ignore")

# %%
# Get the data

p1 = 252

ticker1 = "PETR4.SA" 
df1 = yf.download(ticker1, "2012-01-01", "2022-12-31")
df1["Retornos"] = df1["Adj Close"].pct_change(1)
df1["Adj Low"] = df1["Low"] - (df1["Close"]-df1["Adj Close"])
df1["Adj High"] = df1["High"] - (df1["Close"]-df1["Adj Close"])
df1["Adj Open"] = df1["Open"] - (df1["Close"]-df1["Adj Close"])
df1["Vol"] = df1["Retornos"].rolling(20).std()*np.sqrt(252)
df1.dropna(axis = 0, inplace = True) 
df1.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2012-01-31  24.750000  24.940001  24.330000  24.570000   9.809544  28139600
# 2012-02-01  24.700001  25.170000  24.629999  24.950001   9.961260  24357500
# 2012-02-02  24.879999  25.219999  24.450001  24.530001   9.793574  26639600
# 2012-02-03  24.469999  24.930000  24.370001  24.610001   9.825515  20308300
# 2012-02-06  24.490000  24.860001  24.400000  24.860001   9.925326  14430800
#
#             Retornos   Adj Low   Adj High   Adj Open       Vol
# Date
# 2012-01-31  0.000000  9.569544  10.179544   9.989544  0.254916
# 2012-02-01  0.015466  9.641258  10.181259   9.711260  0.226040
# 2012-02-02 -0.016834  9.713574  10.483573  10.143573  0.239330
# 2012-02-03  0.003261  9.585515  10.145514   9.685513  0.232028
# 2012-02-06  0.010158  9.465325   9.925326   9.555326  0.232175

# %%
# Construção do alvo

# Alvo 1 - Volatilidade
df1["Alvo1"] = df1["Vol"].shift(-10)

# Criação do alvo categórico
df1["Alvo1_cat"] = np.where(df1["Alvo1"] > 0 , 1, 0)

# %%
# Variáveis

df1["MA5"] = df1["Adj Close"].rolling(5).mean()
df1["MA10"] = df1["Adj Close"].rolling(10).mean()
df1["MA20"] = df1["Adj Close"].rolling(20).mean()
df1["MA52"] = df1["Adj Close"].rolling(52).mean()

df1["RSL5"] = df1["Adj Close"]/df1["MA5"]-1
df1["RSL10"] = df1["Adj Close"]/df1["MA10"]-1
df1["RSL20"] = df1["Adj Close"]/df1["MA20"]-1
df1["RSL52"] = df1["Adj Close"]/df1["MA52"]-1

df1["Std5"] = df1["Retornos"].rolling(5).std()
df1["Std10"] = df1["Retornos"].rolling(10).std()
df1["Std20"] = df1["Retornos"].rolling(20).std()
df1["Std52"] = df1["Retornos"].rolling(52).std()

df1.dropna(inplace = True)

# %%
# Separando os dados com as variaveis em x e o alvo em y

# Separando os dados entre treinamento e teste

# Vamos treinar
start_train = "2012-01-01"
end_train = "2017-12-31"

# Vamos testar
start_test = "2018-01-01"
end_test = "2022-12-31"

df1_train = df1.loc[start_train : end_train]

df1_test = df1.loc[start_test : end_test]


# Separando os dados com as variaveis em x e o alvo em y
 
manter = ["Retornos","RSL5", "RSL10", "RSL20", "RSL52", "Std5", "Std10", "Std20", "Std52"]
x_train = df1_train[manter]
y_train = df1_train["Alvo1"]

x_test = df1_test[manter]
y_test = df1_test["Alvo1"]

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (1416, 9)
# (1222, 9)

# %%
# Treinando o modelo

model = MLPRegressor(hidden_layer_sizes = (20,10,20,20), max_iter = 1000,
                    solver = "adam", verbose = 10, tol = 1e-6, random_state = 42,
                    learning_rate_init = .001, activation = "relu")

model.fit(x_train, y_train) # essa é a linha que treina o modelo!!!!
# Out:
# Iteration 1, loss = 0.16537268
# Iteration 2, loss = 0.08767170
# Iteration 3, loss = 0.03641234
# Iteration 4, loss = 0.01735294
# Iteration 5, loss = 0.01842812
# Iteration 6, loss = 0.01850399
# Iteration 7, loss = 0.01670055
# Iteration 8, loss = 0.01625731
# Iteration 9, loss = 0.01634899
# Iteration 10, loss = 0.01614903
# Iteration 11, loss = 0.01583544
# Iteration 12, loss = 0.01566242
# Iteration 13, loss = 0.01553998
# Iteration 14, loss = 0.01529380
# Iteration 15, loss = 0.01517138
# Iteration 16, loss = 0.01498504
# Iteration 17, loss = 0.01481135
# Iteration 18, loss = 0.01462903
# Iteration 19, loss = 0.01443100
# Iteration 20, loss = 0.01424117
# Iteration 21, loss = 0.01403303
# Iteration 22, loss = 0.01384384
# Iteration 23, loss = 0.01362024
# Iteration 24, loss = 0.01327173
# Iteration 25, loss = 0.01302048
# Iteration 26, loss = 0.01272464
# Iteration 27, loss = 0.01252479
# Iteration 28, loss = 0.01228970
# Iteration 29, loss = 0.01198651
# Iteration 30, loss = 0.01171088
# Iteration 31, loss = 0.01150081
# Iteration 32, loss = 0.01126242
# Iteration 33, loss = 0.01103439
# Iteration 34, loss = 0.01079251
# Iteration 35, loss = 0.01062774
# Iteration 36, loss = 0.01032454
# Iteration 37, loss = 0.01009639
# Iteration 38, loss = 0.00985603
# Iteration 39, loss = 0.00961489
# Iteration 40, loss = 0.00954175
# Iteration 41, loss = 0.00909674
# Iteration 42, loss = 0.00893132
# Iteration 43, loss = 0.00867551
# Iteration 44, loss = 0.00838621
# Iteration 45, loss = 0.00819830
# Iteration 46, loss = 0.00799641
# Iteration 47, loss = 0.00764481
# Iteration 48, loss = 0.00741915
# Iteration 49, loss = 0.00721302
# Iteration 50, loss = 0.00705955
# Iteration 51, loss = 0.00673309
# Iteration 52, loss = 0.00650878
# Iteration 53, loss = 0.00630388
# Iteration 54, loss = 0.00609787
# Iteration 55, loss = 0.00592144
# Iteration 56, loss = 0.00577599
# Iteration 57, loss = 0.00557330
# Iteration 58, loss = 0.00542471
# Iteration 59, loss = 0.00520833
# Iteration 60, loss = 0.00515707
# Iteration 61, loss = 0.00497153
# Iteration 62, loss = 0.00478833
# Iteration 63, loss = 0.00467772
# Iteration 64, loss = 0.00458483
# Iteration 65, loss = 0.00448994
# Iteration 66, loss = 0.00445939
# Iteration 67, loss = 0.00440224
# Iteration 68, loss = 0.00442844
# Iteration 69, loss = 0.00423157
# Iteration 70, loss = 0.00417096
# Iteration 71, loss = 0.00413229
# Iteration 72, loss = 0.00408536
# Iteration 73, loss = 0.00400758
# Iteration 74, loss = 0.00406707
# Iteration 75, loss = 0.00394548
# Iteration 76, loss = 0.00388583
# Iteration 77, loss = 0.00396352
# Iteration 78, loss = 0.00393269
# Iteration 79, loss = 0.00380448
# Iteration 80, loss = 0.00375590
# Iteration 81, loss = 0.00375211
# Iteration 82, loss = 0.00375869
# Iteration 83, loss = 0.00368048
# Iteration 84, loss = 0.00366546
# Iteration 85, loss = 0.00366760
# Iteration 86, loss = 0.00370942
# Iteration 87, loss = 0.00368973
# Iteration 88, loss = 0.00363863
# Iteration 89, loss = 0.00362213
# Iteration 90, loss = 0.00359196
# Iteration 91, loss = 0.00360388
# Iteration 92, loss = 0.00366572
# Iteration 93, loss = 0.00367294
# Iteration 94, loss = 0.00356297
# Iteration 95, loss = 0.00351796
# Iteration 96, loss = 0.00356355
# Iteration 97, loss = 0.00352901
# Iteration 98, loss = 0.00351409
# Iteration 99, loss = 0.00355058
# Iteration 100, loss = 0.00349964
# Iteration 101, loss = 0.00352364
# Iteration 102, loss = 0.00349625
# Iteration 103, loss = 0.00352415
# Iteration 104, loss = 0.00350041
# Iteration 105, loss = 0.00350202
# Iteration 106, loss = 0.00347231
# Iteration 107, loss = 0.00346264
# Iteration 108, loss = 0.00347653
# Iteration 109, loss = 0.00344746
# Iteration 110, loss = 0.00344756
# Iteration 111, loss = 0.00349809
# Iteration 112, loss = 0.00345171
# Iteration 113, loss = 0.00356849
# Iteration 114, loss = 0.00346329
# Iteration 115, loss = 0.00356535
# Iteration 116, loss = 0.00378131
# Iteration 117, loss = 0.00394395
# Iteration 118, loss = 0.00364763
# Iteration 119, loss = 0.00352182
# Iteration 120, loss = 0.00345754
# Training loss did not improve more than tol=0.000001 for 10 consecutive epochs. Stopping.
# MLPRegressor(hidden_layer_sizes=(20, 10, 20, 20), max_iter=1000,
#              random_state=42, tol=1e-06, verbose=10)

# %%
# Predições para o treinamento e teste
y_pred_train = model.predict(x_train)
y_pred_test = model.predict(x_test)

# %%
# Avaliação dos resultados

MAE_train = metrics.mean_absolute_error(y_train, y_pred_train) 
R2_train = metrics.r2_score(y_train, y_pred_train) # Coeficiente de determinaçao
RMSE_train = sqrt(metrics.mean_squared_error(y_train, y_pred_train))

print("----- Avaliaçao do treinamento -----")
print("MAE: ", round(MAE_train,2))
print('R2: ', round(R2_train,2))
print('RMSE: ', round(RMSE_train,2))

MAE_test = metrics.mean_absolute_error(y_test, y_pred_test) 
R2_test = metrics.r2_score(y_test, y_pred_test)
RMSE_test = sqrt(metrics.mean_squared_error(y_test, y_pred_test))

print("")
print("----- Avaliaçao do teste -----")
print("MAE: ", round(MAE_test,2))
print('R2: ', round(R2_test,2))
print('RMSE: ', round(RMSE_test,2))
# Out:
# ----- Avaliaçao do treinamento -----
# MAE:  0.06
# R2:  0.81
# RMSE:  0.08
#
# ----- Avaliaçao do teste -----
# MAE:  0.08
# R2:  0.62
# RMSE:  0.15

# %%
# Resultados: Real x previsto em um dataframe

resultados = pd.DataFrame({'Real': y_test, 'Previsto': y_pred_test})
resultados["Residuos"] = resultados["Real"] - resultados["Previsto"]
resultados
# Out:
#                 Real  Previsto  Residuos
# Date
# 2018-01-02  0.203918  0.275978 -0.072060
# 2018-01-03  0.228571  0.269844 -0.041273
# 2018-01-04  0.236636  0.266507 -0.029871
# 2018-01-05  0.205889  0.255883 -0.049994
# 2018-01-08  0.199461  0.252013 -0.052552
# ...              ...       ...       ...
# 2022-11-30  0.468980  0.486859 -0.017879
# 2022-12-01  0.481711  0.521770 -0.040059
# 2022-12-02  0.479137  0.505832 -0.026695
# 2022-12-05  0.482810  0.492926 -0.010116
# 2022-12-06  0.495627  0.467838  0.027789
#
# [1222 rows x 3 columns]

# %%
# Avaliando os resultados

fig = make_subplots(rows = 1, cols = 1
                    , shared_xaxes = True
                    , vertical_spacing = 0.05)

fig.add_trace(go.Scatter(x = resultados.index, y = resultados["Previsto"].rolling(5).mean()
                                , name = "Rede Neural"
                                , line = dict(color = "red"))
              , row = 1, col = 1)

fig.add_trace(go.Scatter(x = resultados.index, y = resultados["Real"].rolling(5).mean()
                                , name = "Real"
                                , line = dict(color = "blue"))
              , row = 1, col = 1)

fig.update_layout(height = 600, width = 800
                  , title_text = "Volatilidade " + ticker1 + " - Real x Previsto"
                  , font_color = "blue"
                  , title_font_color = "black"
                  , xaxis_title = "Tempo"
                  , yaxis_title = "Volatilidade"
                  , font = dict(size = 15, color = "Black")
                 )
fig.show()
# Out:
# <div>                            <div id="6c6a7ba7-b072-429b-8c1e-c930a86144ff" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c6a7ba7-b072-429b-8c1e-c930a86144ff")) {                    Plotly.newPlot(                        "6c6a7ba7-b072-429b-8c1e-c930a86144ff",                        [{"line":{"color":"red"},"name":"Rede Neural","x":["2018-01-02T00:00:00","2018-01-03T00:00:00","2018-01-04T00:00:00","2018-01-05T00:00:00","2018-01-08T00:00:00","2018-01-09T00:00:00","2018-01-10T00:00:00","2018-01-11T00:00:00","2018-01-12T00:00:00","2018-01-15T00:00:00","2018-01-16T00:00:00","2018-01-17T00:00:00","2018-01-18T00:00:00","2018-01-19T00:00:00","2018-01-22T00:00:00","2018-01-23T00:00:00","2018-01-24T00:00:00","2018-01-25T00:00:00","2018-01-26T00:00:00","2018-01-29T00:00:00","2018-01-30T00:00:00","2018-01-31T00:00:00","2018-02-01T00:00:00","2018-02-02T00:00:00","2018-02-05T00:00:00","2018-02-06T00:00:00","2018-02-07T00:00:00","2018-02-08T00:00:00","2018-02-09T00:00:00","2018-02-14T00:00:00","2018-02-15T00:00:00","2018-02-16T00:00:00","2018-02-19T00:00:00","2018-02-20T00:00:00","2018-02-21T00:00:00","2018-02-22T00:00:00","2018-02-23T00:00:00","2018-02-26T00:00:00","2018-02-27T00:00:00","2018-02-28T00:00:00","2018-03-01T00:00:00","2018-03-02T00:00:00","2018-03-05T00:00:00","2018-03-06T00:00:00","2018-03-07T00:00:00","2018-03-08T00:00:00","2018-03-09T00:00:00","2018-03-12T00:00:00","2018-03-13T00:00:00","2018-03-14T00:00:00","2018-03-15T00:00:00","2018-03-16T00:00:00","2018-03-19T00:00:00","2018-03-20T00:00:00","2018-03-21T00:00:00","2018-03-22T00:00:00","2018-03-23T00:00:00","2018-03-26T00:00:00","2018-03-27T00:00:00","2018-03-28T00:00:00","2018-03-29T00:00:00","2018-04-02T00:00:00","2018-04-03T00:00:00","2018-04-04T00:00:00","2018-04-05T00:00:00","2018-04-06T00:00:00","2018-04-09T00:00:00","2018-04-10T00:00:00","2018-04-11T00:00:00","2018-04-12T00:00:00","2018-04-13T00:00:00","2018-04-16T00:00:00","2018-04-17T00:00:00","2018-04-18T00:00:00","2018-04-19T00:00:00","2018-04-20T00:00:00","2018-04-23T00:00:00","2018-04-24T00:00:00","2018-04-25T00:00:00","2018-04-26T00:00:00","2018-04-27T00:00:00","2018-04-30T00:00:00","2018-05-02T00:00:00","2018-05-03T00:00:00","2018-05-04T00:00:00","2018-05-07T00:00:00","2018-05-08T00:00:00","2018-05-09T00:00:00","2018-05-10T00:00:00","2018-05-11T00:00:00","2018-05-14T00:00:00","2018-05-15T00:00:00","2018-05-16T00:00:00","2018-05-17T00:00:00","2018-05-18T00:00:00","2018-05-21T00:00:00","2018-05-22T00:00:00","2018-05-23T00:00:00","2018-05-24T00:00:00","2018-05-25T00:00:00","2018-05-28T00:00:00","2018-05-29T00:00:00","2018-05-30T00:00:00","2018-06-01T00:00:00","2018-06-04T00:00:00","2018-06-05T00:00:00","2018-06-06T00:00:00","2018-06-07T00:00:00","2018-06-08T00:00:00","2018-06-11T00:00:00","2018-06-12T00:00:00","2018-06-13T00:00:00","2018-06-14T00:00:00","2018-06-15T00:00:00","2018-06-18T00:00:00","2018-06-19T00:00:00","2018-06-20T00:00:00","2018-06-21T00:00:00","2018-06-22T00:00:00","2018-06-25T00:00:00","2018-06-26T00:00:00","2018-06-27T00:00:00","2018-06-28T00:00:00","2018-06-29T00:00:00","2018-07-02T00:00:00","2018-07-03T00:00:00","2018-07-04T00:00:00","2018-07-05T00:00:00","2018-07-06T00:00:00","2018-07-10T00:00:00","2018-07-11T00:00:00","2018-07-12T00:00:00","2018-07-13T00:00:00","2018-07-16T00:00:00","2018-07-17T00:00:00","2018-07-18T00:00:00","2018-07-19T00:00:00","2018-07-20T00:00:00","2018-07-23T00:00:00","2018-07-24T00:00:00","2018-07-25T00:00:00","2018-07-26T00:00:00","2018-07-27T00:00:00","2018-07-30T00:00:00","2018-07-31T00:00:00","2018-08-01T00:00:00","2018-08-02T00:00:00","2018-08-03T00:00:00","2018-08-06T00:00:00","2018-08-07T00:00:00","2018-08-08T00:00:00","2018-08-09T00:00:00","2018-08-10T00:00:00","2018-08-13T00:00:00","2018-08-14T00:00:00","2018-08 ...
